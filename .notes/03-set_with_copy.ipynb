# %%
import pandas as pd

# %%
df = pd.read_csv('../data/gapminder.tsv', sep='\t')

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.country.value_counts().index.str.contains('Costa')
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
# ...

# %%
df[df.country == 'Costa Rica']
# Out:
#         country continent  year  lifeExp      pop    gdpPercap
# 348  Costa Rica  Americas  1952   57.206   926317  2627.009471
# 349  Costa Rica  Americas  1957   60.026  1112300  2990.010802
# 350  Costa Rica  Americas  1962   62.842  1345187  3460.937025
# 351  Costa Rica  Americas  1967   65.424  1588717  4161.727834
# 352  Costa Rica  Americas  1972   67.849  1834796  5118.146939
# 353  Costa Rica  Americas  1977   70.750  2108457  5926.876967
# 354  Costa Rica  Americas  1982   73.450  2424367  5262.734751
# 355  Costa Rica  Americas  1987   74.752  2799811  5629.915318
# 356  Costa Rica  Americas  1992   75.713  3173216  6160.416317
# 357  Costa Rica  Americas  1997   77.260  3518107  6677.045314
# 358  Costa Rica  Americas  2002   78.123  3834934  7723.447195
# 359  Costa Rica  Americas  2007   78.782  4133884  9645.061420

# %%
# get item and set item
df[df.country == 'Costa Rica'].continent = 'South America'
# Out:
# C:\Users\Danie\Anaconda3\lib\site-packages\pandas\core\generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df[df.country == 'Costa Rica']
# Out:
#         country continent  year  lifeExp      pop    gdpPercap
# 348  Costa Rica  Americas  1952   57.206   926317  2627.009471
# 349  Costa Rica  Americas  1957   60.026  1112300  2990.010802
# 350  Costa Rica  Americas  1962   62.842  1345187  3460.937025
# 351  Costa Rica  Americas  1967   65.424  1588717  4161.727834
# 352  Costa Rica  Americas  1972   67.849  1834796  5118.146939
# 353  Costa Rica  Americas  1977   70.750  2108457  5926.876967
# 354  Costa Rica  Americas  1982   73.450  2424367  5262.734751
# 355  Costa Rica  Americas  1987   74.752  2799811  5629.915318
# 356  Costa Rica  Americas  1992   75.713  3173216  6160.416317
# 357  Costa Rica  Americas  1997   77.260  3518107  6677.045314
# 358  Costa Rica  Americas  2002   78.123  3834934  7723.447195
# 359  Costa Rica  Americas  2007   78.782  4133884  9645.061420

# %%
df.loc[df.country == 'Costa Rica', 'continent'] = 'South America'

# %%
df[df.country == 'Costa Rica']
# Out:
#         country      continent  year  lifeExp      pop    gdpPercap
# 348  Costa Rica  South America  1952   57.206   926317  2627.009471
# 349  Costa Rica  South America  1957   60.026  1112300  2990.010802
# 350  Costa Rica  South America  1962   62.842  1345187  3460.937025
# 351  Costa Rica  South America  1967   65.424  1588717  4161.727834
# 352  Costa Rica  South America  1972   67.849  1834796  5118.146939
# 353  Costa Rica  South America  1977   70.750  2108457  5926.876967
# 354  Costa Rica  South America  1982   73.450  2424367  5262.734751
# 355  Costa Rica  South America  1987   74.752  2799811  5629.915318
# 356  Costa Rica  South America  1992   75.713  3173216  6160.416317
# 357  Costa Rica  South America  1997   77.260  3518107  6677.045314
# 358  Costa Rica  South America  2002   78.123  3834934  7723.447195
# 359  Costa Rica  South America  2007   78.782  4133884  9645.061420

# %%
# https://tomaugspurger.github.io/modern-1-intro.html

# %%
cr = df.loc[df.country == 'Costa Rica']

# %%
cr
# Out:
#         country      continent  year  lifeExp      pop    gdpPercap
# 348  Costa Rica  South America  1952   57.206   926317  2627.009471
# 349  Costa Rica  South America  1957   60.026  1112300  2990.010802
# 350  Costa Rica  South America  1962   62.842  1345187  3460.937025
# 351  Costa Rica  South America  1967   65.424  1588717  4161.727834
# 352  Costa Rica  South America  1972   67.849  1834796  5118.146939
# 353  Costa Rica  South America  1977   70.750  2108457  5926.876967
# 354  Costa Rica  South America  1982   73.450  2424367  5262.734751
# 355  Costa Rica  South America  1987   74.752  2799811  5629.915318
# 356  Costa Rica  South America  1992   75.713  3173216  6160.416317
# 357  Costa Rica  South America  1997   77.260  3518107  6677.045314
# 358  Costa Rica  South America  2002   78.123  3834934  7723.447195
# 359  Costa Rica  South America  2007   78.782  4133884  9645.061420

# %%
cr['continent'] = 'Americas'
# Out:
# C:\Users\Danie\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
cr
# Out:
#         country continent  year  lifeExp      pop    gdpPercap
# 348  Costa Rica  Americas  1952   57.206   926317  2627.009471
# 349  Costa Rica  Americas  1957   60.026  1112300  2990.010802
# 350  Costa Rica  Americas  1962   62.842  1345187  3460.937025
# 351  Costa Rica  Americas  1967   65.424  1588717  4161.727834
# 352  Costa Rica  Americas  1972   67.849  1834796  5118.146939
# 353  Costa Rica  Americas  1977   70.750  2108457  5926.876967
# 354  Costa Rica  Americas  1982   73.450  2424367  5262.734751
# 355  Costa Rica  Americas  1987   74.752  2799811  5629.915318
# 356  Costa Rica  Americas  1992   75.713  3173216  6160.416317
# 357  Costa Rica  Americas  1997   77.260  3518107  6677.045314
# 358  Costa Rica  Americas  2002   78.123  3834934  7723.447195
# 359  Costa Rica  Americas  2007   78.782  4133884  9645.061420

# %%
cr = df.loc[df.country == 'Costa Rica'].copy()

# %%
cr['continent'] = 'Americas'

# %%
c
